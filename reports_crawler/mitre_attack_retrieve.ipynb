# %%
import os
import sys
import pandas
from bs4 import BeautifulSoup
import networkx as nx

# %%
G = nx.Graph()

# %%
import matplotlib.pyplot as plt
# G =nx.random_graphs.barabasi_albert_graph(100,1)
# nx.draw(G)

plt.figure(figsize=(18,18))

graph_pos = nx.spring_layout(G)
nx.draw_networkx_nodes(G, graph_pos, node_size=10, node_color='blue', alpha=0.3)
nx.draw_networkx_edges(G, graph_pos)
nx.draw_networkx_labels(G, graph_pos, font_size=8, font_family='sans-serif')

# plt.show()
plt.savefig("plot.pdf")
# Out:
# c:\python39\lib\site-packages\matplotlib\backends\_backend_pdf_ps.py:109: RuntimeWarning: Glyph 30450 missing from current font.
#   font.set_text(s, 0.0, flags=ft2font.LOAD_NO_HINTING)
# c:\python39\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 30450 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\python39\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 30450 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
plt.savefig("plot.pdf")

# %%
# Save graph
nx.write_gml(G, "mitre_attack.gml")

# %%
# # Read graph
G = nx.read_gml('mitre_attack.gml')

# %%
soup = BeautifulSoup(open(r"C:\Users\DX\Desktop\MITRE ATT&CK.html"))

table = soup.find_all("table")[1]

# %%
table
# Out:
# <table class="matrix side">
# <thead>
# <tr>
# <td class="tactic name"><a data-placement="top" data-toggle="tooltip" href="/tactics/TA0043" title="TA0043">Reconnaissance</a></td>
# <td class="tactic name"><a data-placement="top" data-toggle="tooltip" href="/tactics/TA0042" title="TA0042">Resource Development</a></td>
# <td class="tactic name"><a data-placement="top" data-toggle="tooltip" href="/tactics/TA0001" title="TA0001">Initial Access</a></td>
# <td class="tactic name"><a data-placement="top" data-toggle="tooltip" href="/tactics/TA0002" title="TA0002">Execution</a></td>
# <td class="tactic name"><a data-placement="top" data-toggle="tooltip" href="/tactics/TA0003" title="TA0003">Persistence</a></td>
# <td class="tactic name"><a data-placement="top" data-toggle="tooltip" href="/tactics/TA0004" title="TA0004">Privilege Escalation</a></td>
# <td class="tactic name"><a data-placement="top" data-toggle="tooltip" href="/tactics/TA0005" title="TA0005">Defense Evasion</a></td>
# <td class="tactic name"><a data-placement="top" data-toggle="tooltip" href="/tactics/TA0006" title="TA0006">Credential Access</a></td>
# <td class="tactic name"><a data-placement="top" data-toggle="tooltip" href="/tactics/TA0007" title="TA0007">Discovery</a></td>
# <td class="tactic name"><a data-placement="top" data-toggle="tooltip" href="/tactics/TA0008" title="TA0008">Lateral Movement</a></td>
# <td class="tactic name"><a data-placement="top" data-toggle="tooltip" href="/tactics/TA0009" title="TA0009">Collection</a></td>
# <td class="tactic name"><a data-placement="top" data-toggle="tooltip" href="/tactics/TA0011" title="TA0011">Command and Control</a></td>
# <td class="tactic name"><a data-placement="top" data-toggle="tooltip" href="/tactics/TA0010" title="TA0010">Exfiltration</a></td>
# <td class="tactic name"><a data-placement="top" data-toggle="tooltip" href="/tactics/TA0040" title="TA0040">Impact</a></td>
# </tr>
# <tr>
# <td class="tactic count">
#                     10 techniques
#                 </td>
# <td class="tactic count">
#                     6 techniques
#                 </td>
# <td class="tactic count">
#                     9 techniques
#                 </td>
# <td class="tactic count">
#                     10 techniques
#                 </td>
# <td class="tactic count">
#                     18 techniques
#                 </td>
# <td class="tactic count">
#                     12 techniques
#                 </td>
# <td class="tactic count">
#                     37 techniques
#                 </td>
# <td class="tactic count">
#                     15 techniques
#                 </td>
# <td class="tactic count">
#                     25 techniques
#                 </td>
# <td class="tactic count">
#                     9 techniques
#                 </td>
# <td class="tactic count">
#                     17 techniques
#                 </td>
# <td class="tactic count">
#                     16 techniques
#                 </td>
# <td class="tactic count">
#                     9 techniques
#                 </td>
# <td class="tactic count">
#                     13 techniques
#                 </td>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td class="tactic">
# <table class="techniques-table">
# <!-- tour technique is scheduled task under privilege escalation -->
# <tr class="technique-row">
# <td>
# <table class="supertechnique">
# <tr>
# <td class="technique">
# <div class="technique-cell supertechniquecell">
# <a data-placement="top" data-toggle="tooltip" href="/techniques/T1595" title="T1595">Active Scanning <sub>(2)</sub></a>
# </div>
# </td>
# </tr>
# </table>
# </td>
# <td class="sidebar sidebar--x-mitre-tactic--daa4cbb1-b4f4-4723-a824-7f1efd6e0592--attack-pattern--67073dde-d720-45ae-83da-b12d5e73ca3b" onclick="matrix_toggle_technique('x-mitre-tactic--daa4cbb1-b4f4-4723-a824-7f1efd6e0592', 'attack-pattern--67073dde-d720-45ae-83da-b12d5e73ca3b');">
# <div class="angle top">
# <svg height="12px" width="12px">
# <path d="M0 12H12V0Z"></path>
# </svg>
# </div>
# <div class="handle"> = </div>
# <div class="angle bottom">
# <svg height="12px" width="12px">
# <path d="M0 0H12V12Z"></path>
# </svg>
# </div>
# </td>
# <td class="subtechniques-td">
# <div class="subtechniques hidden subtechniques-container subtechniques--x-mitre-tactic--daa4cbb1-b4f4-4723-a824-7f1efd6e0592--attack-pattern--67073dde-d720-45ae-83da-b12d5e73ca3b">
# <div class="subtechnique">
# <div class="technique-cell">
# <a data-placement="top" data-toggle="tooltip" href="/techniques/T1595/001" title="T1595.001">Scanning IP Blocks</a>
# </div>
# </div>
# <div class="subtechnique">
# <div class="technique-cell">
# <a data-placement="top" data-toggle="tooltip" href="/techniques/T1595/002" title="T1595.002">Vulnerability Scanning</a>
# </div>
# </div>
# </div>
# </td>
# </tr>
# <!-- tour technique is scheduled task under privilege escalation -->
# <tr class="technique-row" id="tour-side-technique">
# <td>
# <table class="supertechnique">
# <tr>
# <td class="technique">
# <div class="technique-cell supertechniquecell">
# <a data-placement="top" data-toggle="tooltip" href="/techniques/T1592" title="T1592">Gather Victim Host Information <sub>(4)</sub></a>
# </div>
# </td>
# </tr>
# </table>
# </td>
# <td class="sidebar sidebar--x-mitre-tactic--daa4cbb1-b4f4-4723-a824-7f1efd6e0592--attack-pattern--09312b1a-c3c6-4b45-9844-3ccc78e5d82f sidebar--tour" onclick="matrix_toggle_technique('x-mitre-tactic--daa4cbb1-b4f4-4723-a824-7f1efd6e0592', 'attack-pattern--09312b1a-c3c6-4b45-9844-3ccc78e5d82f'); tour_technique_clicked();">
# <div class="angle top">
# <svg height="12px" width="12px">
# <path d="M0 12H12V0Z"></path>
# </svg>
# </div>
# <div class="handle"> = </div>
# <div class="angle bottom">
# <svg height="12px" width="12px">
# <path d="M0 0H12V12Z"></path>
# </svg>
# </div>
# </td>
# <td class="subtechniques-td" id="tour-side-subtechniques">
# <div class="subtechniques hidden subtechniques-container subtechniques--x-mitre-tactic--daa4cbb1-b4f4-4723-a824-7f1efd6e0592--attack-pattern--09312b1a-c3c6-4b45-9844-3ccc78e5d82f subtechniques--tour">
# <div class="subtechnique">
# <div class="technique-cell">
# <a data-placement="top" data-toggle="tooltip" href="/techniques/T1592/001" title="T1592.001">Hardware</a>
# </div>
# </div>
# <div class="subtechnique">
# <div class="technique-cell">
# <a data-placement="top" data-toggle="tooltip" href="/techniques/T1592/002" title="T1592.002">Software</a>
# </div>
# </div>
# <div class="subtechnique">
# <div class="technique-cell">
# <a data-placement="top" data-toggle="tooltip" href="/techniques/T1592/003" title="T1592.003">Firmware</a>
# </div>
# </div>
# <div class="subtechnique">
# <div class="technique-cell">
# <a data-placement="top" data-toggle="tooltip" href="/techniques/T1592/004" title="T1592.004">Client Configurations</a>
# </div>
# </div>
# </div>
# </td>
# </tr>
# <!-- tour technique is scheduled task under privilege escalation -->
# <tr class="technique-row">
# <td>
# <table class="supertechnique">
# <tr>
# <td class="technique">
# <div class="technique-cell supertechniquecell">
# <a data-placement="top" data-toggle="tooltip" href="/techniques/T1589" title="T1589">Gather Victim Identity Information <sub>(3)</sub></a>
# </div>
# </td>
# </tr>
# </table>
# </td>
# <td class="sidebar sidebar--x-mitre-tactic--daa4cbb1-b4f4-4723-a824-7f1efd6e0592--attack-pattern--5282dd9a-d26d-4e16-88b7-7c0f4553daf4" onclick="matrix_toggle_technique('x-mitre-tactic--daa4cbb1-b4f4-4723-a824-7f1efd6e0592', 'attack-pattern--5282dd9a-d26d-4e16-88b7-7c0f4553daf4');">
# <div class="angle top">
# <svg height="12px" width="12px">
# <path d="M0 12H12V0Z"></path>
# </svg>
# </div>
# <div class="handle"> = </div>
# <div class="angle bottom">
# <svg height="12px" width="12px">
# <path d="M0 0H12V12Z"></path>
# </svg>
# </div>
# </td>
# <td class="subtechniques-td">
# <div class="subtechniques hidden subtechniques-container subtechniques--x-mitre-tactic--daa4cbb1-b4f4-4723-a824-7f1efd6e0592--attack-pattern--5282dd9a-d26d-4e16-88b7-7c0f4553daf4">
# <div class="subtechnique">
# <div class="technique-cell">
# <a data-placement="top" data-toggle="tooltip" href="/techniques/T1589/001" title="T1589.001">Credentials</a>
# </div>
# </div>
# <div class="subtechnique">
# <div class="technique-cell">
# <a data-placement="top" data-toggle="tooltip" href="/techniques/T1589/002" title="T1589.002">Email Addresses</a>
# </div>
# </div>
# <div class="subtechnique">
# <div class="technique-cell">
# <a data-placement="top" data-toggle="tooltip" href="/techniques/T1589/003" title="T1589.003">Employee Names</a>
# </div>
# </div>
# </div>
# </td>
# </tr>
# <!-- tour technique is scheduled task under privilege escalation -->
# <tr class="technique-row">
# <td>
# <table class="supertechnique">
# <tr>
# <td class="technique">
# <div class="technique-cell supertechniquecell">
# <a data-placement="top" data-toggle="tooltip" href="/techniques/T1590" title="T1590">Gather Victim Network Information <sub>(6)</sub></a>
# </div>
# </td>
# </tr>
# </table>
# </td>
# <td class="sidebar sidebar--x-mitre-tactic--daa4cbb1-b4f4-4723-a824-7f1efd6e0592--attack-pattern--9d48cab2-7929-4812-ad22-f536665f0109" onclick="matrix_toggle_technique('x-mitre-tactic--daa4cbb1-b4f4-4723-a824-7f1efd6e0592', 'attack-pattern--9d48cab2-7929-4812-ad22-f536665f0109');">
# <div class="angle top">
# <svg height="12px" width="12px">
# <path d="M0 12H12V0Z"></path>
# </svg>
# </div>
# <div class="handle"> = </div>
# <div class="angle bottom">
# <svg height="12px" width="12px">
# <path d="M0 0H12V12Z"></path>
# </svg>
# </div>
# </td>
# <td class="subtechniques-td">
# <div class="subtechniques hidden subtechniques-container subtechniques--x-mitre-tactic--daa4cbb1-b4f4-4723-a824-7f1efd6e0592--attack-pattern--9d48cab2-7929-4812-ad22-f536665f0109">
# <div class="subtechnique">
# <div class="technique-cell">
# <a data-placement="top" data-toggle="tooltip" href="/techniques/T1590/001" title="T1590.001">Domain Properties</a>
# </div>
# </div>
# <div class="subtechnique">
# <div class="technique-cell">
# <a data-placement="top" data-toggle="tooltip" href="/techniques/T1590/002" title="T1590.002">DNS</a>
# </div>
# </div>
# <div class="subtechnique">
# <div class="technique-cell">
# <a data-placement="top" data-toggle="tooltip" href="/techniques/T1590/003" title="T1590.003">Network Trust Dependencies</a>
# </div>
# </div>
# <div class="subtechnique">
# <div class="technique-cell">
# <a data-placement="top" data-toggle="tooltip" href="/techniques/T1590/004" title="T1590.004">Network Topology</a>
# </div>
# </div>
# <div class="subtechnique">
# <div class="technique-cell">
# <a data-placement="top" data-toggle="tooltip" href="/techniques/T1590/005" title="T1590.005">IP Addresses</a>
# </div>
# </div>
# <div class="subtechnique">
# <div class="technique-cell">
# <a data-placement="top" data-toggle="tooltip" href="/techniques/T1590/006" title="T1590.006">Network Security Appliances</a>
# </div>
# </div>
# </div>
# </td>
# </tr>
# <!-- tour technique is scheduled task under privilege escalation -->
# <tr class="technique-row">
# <td>
# <table class="supertechnique">
# <tr>
# <td class="technique">
# <div class="technique-cell supertechniquecell">
# <a data-placement="top" data-toggle="tooltip" href="/techniques/T1591" title="T1591">Gather Victim Org Information <sub>(4)</sub></a>
# </div>
# </td>
# </tr>
# </table>
# </td>
# <td class="sidebar sidebar--x-mitre-tactic--daa4cbb1-b4f4-4723-a824-7f1efd6e0592--attack-pattern--937e4772-8441-4e4a-8bf0-8d447d667e23" onclick="matrix_toggle_technique('x-mitre-tactic--daa4cbb1-b4f4-4723-a824-7f1efd6e0592', 'attack-pattern--937e4772-8441-4e4a-8bf0-8d447d667e23');">
# <div class="angle top">
# <svg height="12px" width="12px">
# <path d="M0 12H12V0Z"></path>
# </svg>
# </div>
# <div class="handle"> = </div>
# <div class="angle bottom">
# <svg height="12px" width="12px">
# <path d="M0 0H12V12Z"></path>
# </svg>
# </div>
# </td>
# <td class="subtechniques-td">
# <div class="subtechniques hidden subtechniques-container subtechniques--x-mitre-tactic--daa4cbb1-b4f4-4723-a824-7f1efd6e0592--attack-pattern--937e4772-8441-4e4a-8bf0-8d447d667e23">
# <div class="subtechnique">
# <div class="technique-cell">
# <a data-placement="top" data-toggle="tooltip" href="/techniques/T1591/002" title="T1591.002">Business Relationships</a>
# </div>
# </div>
# <div class="subtechnique">
# <div class="technique-cell">
# <a data-placement="top" data-toggle="tooltip" href="/techniques/T1591/001" title="T1591.001">Determine Physical Locations</a>
# </div>
# </div>
# <div class="subtechnique">
# <div class="technique-cell">
# <a data-placement="top" data-toggle="tooltip" href="/techniques/T1591/003" title="T1591.003">Identify Business Tempo</a>
# </div>
# </div>
# <div class="subtechnique">
# <div class="technique-cell">
# <a data-placement="top" data-toggle="tooltip" href="/techniques/T1591/004" title="T1591.004">Identify Roles</a>
# </div>
# </div>
# </div>
# </td>
# </tr>
# <!-- tour technique is scheduled task under privilege escalation -->
# <tr class="technique-row">
# <td>
# <table class="supertechnique">
# <tr>
# <td class="technique">
# <div class="technique-cell supertechniquecell">
# <a data-placement="top" data-toggle="tooltip" href="/techniques/T1598" title="T1598">Phishing for Information <sub>(3)</sub></a>
# </div>
# </td>
# </tr>
# </table>
# </td>
# <td class="sidebar sidebar--x-mitre-tactic--daa4cbb1-b4f4-4723-a824-7f1efd6e0592--attack-pattern--cca0ccb6-a068-4574-a722-b1556f86833a" onclick="matrix_toggle_technique('x-mitre-tactic--daa4cbb1-b4f4-4723-a824-7f1efd6e0592', 'attack-pattern--cca0ccb6-a068-4574-a722-b1556f86833a');">
# <div class="angle top">
# <svg height="12px" width="12px">
# <path d="M0 12H12V0Z"></path>
# </svg>
# </div>
# <div class="handle"> = </div>
# <div class="angle bottom">
# <svg height="12px" width="12px">
# <path d="M0 0H12V12Z"></path>
# </svg>
# </div>
# </td>
# <td class="subtechniques-td">
# <div class="subtechniques hidden subtechniques-container subtechniques--x-mitre-tactic--daa4cbb1-b4f4-4723-a824-7f1efd6e0592--attack-pattern--cca0ccb6-a068-4574-a722-b1556f86833a">
# <div class="subtechnique">
# <div class="technique-cell">
# <a data-placement="top" data-toggle="tooltip" href="/techniques/T
a>
# </div>
# </div>
# <div class="subtechnique">
# <div class="technique-cell">
# <a data-placement="top" data-toggle="tooltip" href="/techniques/T1499/002" title="T1499.002">Service Exhaustion Flood</a>
# </div>
# </div>
# <div class="subtechnique">
# <div class="technique-cell">
# <a data-placement="top" data-toggle="tooltip" href="/techniques/T1499/003" title="T1499.003">Application Exhaustion Flood</a>
# </div>
# </div>
# <div class="subtechnique">
# <div class="technique-cell">
# <a data-placement="top" data-toggle="tooltip" href="/techniques/T1499/004" title="T1499.004">Application or System Exploitation</a>
# </div>
# </div>
# </div>
# </td>
# </tr>
# <!-- tour technique is scheduled task under privilege escalation -->
# <tr class="technique-row">
# <td>
# <div class="technique-cell">
# <a data-placement="top" data-toggle="tooltip" href="/techniques/T1495" title="T1495">Firmware Corruption</a>
# </div>
# </td>
# <td class="subtechniques-td">
# <div class="subtechniques hidden subtechniques-container subtechniques--x-mitre-tactic--5569339b-94c2-49ee-afb3-2222936582c8--attack-pattern--f5bb433e-bdf6-4781-84bc-35e97e43be89">
# </div>
# </td>
# </tr>
# <!-- tour technique is scheduled task under privilege escalation -->
# <tr class="technique-row">
# <td>
# <div class="technique-cell">
# <a data-placement="top" data-toggle="tooltip" href="/techniques/T1490" title="T1490">Inhibit System Recovery</a>
# </div>
# </td>
# <td class="subtechniques-td">
# <div class="subtechniques hidden subtechniques-container subtechniques--x-mitre-tactic--5569339b-94c2-49ee-afb3-2222936582c8--attack-pattern--f5d8eed6-48a9-4cdf-a3d7-d1ffa99c3d2a">
# </div>
# </td>
# </tr>
# <!-- tour technique is scheduled task under privilege escalation -->
# <tr class="technique-row">
# <td>
# <table class="supertechnique">
# <tr>
# <td class="technique">
# <div class="technique-cell supertechniquecell">
# <a data-placement="top" data-toggle="tooltip" href="/techniques/T1498" title="T1498">Network Denial of Service <sub>(2)</sub></a>
# </div>
# </td>
# </tr>
# </table>
# </td>
# <td class="sidebar sidebar--x-mitre-tactic--5569339b-94c2-49ee-afb3-2222936582c8--attack-pattern--d74c4a7e-ffbf-432f-9365-7ebf1f787cab" onclick="matrix_toggle_technique('x-mitre-tactic--5569339b-94c2-49ee-afb3-2222936582c8', 'attack-pattern--d74c4a7e-ffbf-432f-9365-7ebf1f787cab');">
# <div class="angle top">
# <svg height="12px" width="12px">
# <path d="M0 12H12V0Z"></path>
# </svg>
# </div>
# <div class="handle"> = </div>
# <div class="angle bottom">
# <svg height="12px" width="12px">
# <path d="M0 0H12V12Z"></path>
# </svg>
# </div>
# </td>
# <td class="subtechniques-td">
# <div class="subtechniques hidden subtechniques-container subtechniques--x-mitre-tactic--5569339b-94c2-49ee-afb3-2222936582c8--attack-pattern--d74c4a7e-ffbf-432f-9365-7ebf1f787cab">
# <div class="subtechnique">
# <div class="technique-cell">
# <a data-placement="top" data-toggle="tooltip" href="/techniques/T1498/001" title="T1498.001">Direct Network Flood</a>
# </div>
# </div>
# <div class="subtechnique">
# <div class="technique-cell">
# <a data-placement="top" data-toggle="tooltip" href="/techniques/T1498/002" title="T1498.002">Reflection Amplification</a>
# </div>
# </div>
# </div>
# </td>
# </tr>
# <!-- tour technique is scheduled task under privilege escalation -->
# <tr class="technique-row">
# <td>
# <div class="technique-cell">
# <a data-placement="top" data-toggle="tooltip" href="/techniques/T1496" title="T1496">Resource Hijacking</a>
# </div>
# </td>
# <td class="subtechniques-td">
# <div class="subtechniques hidden subtechniques-container subtechniques--x-mitre-tactic--5569339b-94c2-49ee-afb3-2222936582c8--attack-pattern--cd25c1b4-935c-4f0e-ba8d-552f28bc4783">
# </div>
# </td>
# </tr>
# <!-- tour technique is scheduled task under privilege escalation -->
# <tr class="technique-row">
# <td>
# <div class="technique-cell">
# <a data-placement="top" data-toggle="tooltip" href="/techniques/T1489" title="T1489">Service Stop</a>
# </div>
# </td>
# <td class="subtechniques-td">
# <div class="subtechniques hidden subtechniques-container subtechniques--x-mitre-tactic--5569339b-94c2-49ee-afb3-2222936582c8--attack-pattern--20fb2507-d71c-455d-9b6d-6104461cf26b">
# </div>
# </td>
# </tr>
# <!-- tour technique is scheduled task under privilege escalation -->
# <tr class="technique-row">
# <td>
# <div class="technique-cell">
# <a data-placement="top" data-toggle="tooltip" href="/techniques/T1529" title="T1529">System Shutdown/Reboot</a>
# </div>
# </td>
# <td class="subtechniques-td">
# <div class="subtechniques hidden subtechniques-container subtechniques--x-mitre-tactic--5569339b-94c2-49ee-afb3-2222936582c8--attack-pattern--ff73aa03-0090-4464-83ac-f89e233c02bc">
# </div>
# </td>
# </tr>
# </table>
# </td>
# </tr>
# </tbody>
# </table>

# %%
tactic_list = []

head = table.find("thead")
for head_content in head.find_all("a"):
    tactic_name = head_content.text
    tactic_list.append(tactic_name)
    print(tactic_name)
    tactic_url = head_content['href']
    print(tactic_url)
    
    G.add_node(tactic_name, url=tactic_url, types='tactic')
# Out:
# Reconnaissance
# /tactics/TA0043
# Resource Development
# /tactics/TA0042
# Initial Access
# /tactics/TA0001
# Execution
# /tactics/TA0002
# Persistence
# /tactics/TA0003
# Privilege Escalation
# /tactics/TA0004
# Defense Evasion
# /tactics/TA0005
# Credential Access
# /tactics/TA0006
# Discovery
# /tactics/TA0007
# Lateral Movement
# /tactics/TA0008
# Collection
# /tactics/TA0009
# Command and Control
# /tactics/TA0011
# Exfiltration
# /tactics/TA0010
# Impact
# /tactics/TA0040

# %%
body = table.find("tbody")
tactic_count = -1

for body_content in body.find_all('table', {'class': 'techniques-table'}):
    tactic = tactic_list[tactic_count]
    tactic_count += 1
    print(tactic)
    
    print(len(body_content.find_all('table', {'class': 'supertechnique'})))
    
    for technique_row in body_content.find_all('tr', {'class': 'technique-row'}):
#         technique_list = []
        super_technique = technique_row.find_all('table', {'class': 'supertechnique'})
        is_super_technique = len(super_technique) # this value is zero when there is no sub-technique.
        print(is_super_technique) 
        if is_super_technique:
            super_technique_name = super_technique[0].find('a').text
            print(super_technique_name)
            super_technique_url = super_technique[0].find('a')['href']
            print(super_technique_url)
            G.add_node(super_technique_name, url=super_technique_url, types='super_technique')
            G.add_edge(super_technique_name, tactic, type='belong to')
            
            for sub_technique in technique_row.find_all('div', {'class': 'subtechnique'}):
                sub_technique_name = sub_technique.find('a').text
                print(sub_technique_name)
                sub_technique_url = sub_technique.find('a')['href']
                print(sub_technique_url)
                G.add_node(sub_technique_name, url=sub_technique_url, types='sub_technique')
                G.add_edge(sub_technique_name, super_technique_name, types='belong to')
        else:
            technique_name = technique_row.find('a').text
            print(technique_name)
            technique_url = technique_row.find('a')['href']
            print(technique_url)
            G.add_node(technique_name, url=technique_url, types='super_technique')
            G.add_edge(technique_name, tactic, types='belong to')
# Out:
# Impact
# 9
# 1
# Active Scanning (2)
# /techniques/T1595
# Scanning IP Blocks
# /techniques/T1595/001
# Vulnerability Scanning
# /techniques/T1595/002
# 1
# Gather Victim Host Information (4)
# /techniques/T1592
# Hardware
# /techniques/T1592/001
# Software
# /techniques/T1592/002
# Firmware
# /techniques/T1592/003
# Client Configurations
# /techniques/T1592/004
# 1
# Gather Victim Identity Information (3)
# /techniques/T1589
# Credentials
# /techniques/T1589/001
# Email Addresses
# /techniques/T1589/002
# Employee Names
# /techniques/T1589/003
# 1
# Gather Victim Network Information (6)
# /techniques/T1590
# Domain Properties
# /techniques/T1590/001
# DNS
# /techniques/T1590/002
# Network Trust Dependencies
# /techniques/T1590/003
# Network Topology
# /techniques/T1590/004
# IP Addresses
# /techniques/T1590/005
# Network Security Appliances
# /techniques/T1590/006
# 1
# Gather Victim Org Information (4)
# /techniques/T1591
# Business Relationships
# /techniques/T1591/002
# Determine Physical Locations
# /techniques/T1591/001
# Identify Business Tempo
# /techniques/T1591/003
# Identify Roles
# /techniques/T1591/004
# 1
# Phishing for Information (3)
# /techniques/T1598
# Spearphishing Service
# /techniques/T1598/001
# Spearphishing Attachment
# /techniques/T1598/002
# Spearphishing Link
# /techniques/T1598/003
# 1
# Search Closed Sources (2)
# /techniques/T1597
# Threat Intel Vendors
# /techniques/T1597/001
# Purchase Technical Data
# /techniques/T1597/002
# 1
# Search Open Technical Databases (5)
# /techniques/T1596
# WHOIS
# /techniques/T1596/002
# DNS/Passive DNS
# /techniques/T1596/001
# Digital Certificates
# /techniques/T1596/003
# CDNs
# /techniques/T1596/004
# Scan Databases
# /techniques/T1596/005
# 1
# Search Open Websites/Domains (2)
# /techniques/T1593
# Social Media
# /techniques/T1593/001
# Search Engines
# /techniques/T1593/002
# 0
# Search Victim-Owned Websites
# /techniques/T1594
# Reconnaissance
# 6
# 1
# Acquire Infrastructure (6)
# /techniques/T1583
# Domains
# /techniques/T1583/001
# DNS Server
# /techniques/T1583/002
# Virtual Private Server
# /techniques/T1583/003
# Server
# /techniques/T1583/004
# Botnet
# /techniques/T1583/005
# Web Services
# /techniques/T1583/006
# 1
# Compromise Accounts (2)
# /techniques/T1586
# Social Media Accounts
# /techniques/T1586/001
# Email Accounts
# /techniques/T1586/002
# 1
# Compromise Infrastructure (6)
# /techniques/T1584
# Domains
# /techniques/T1584/001
# DNS Server
# /techniques/T1584/002
# Virtual Private Server
# /techniques/T1584/003
# Server
# /techniques/T1584/004
# Botnet
# /techniques/T1584/005
# Web Services
# /techniques/T1584/006
# 1
# Develop Capabilities (4)
# /techniques/T1587
# Malware
# /techniques/T1587/001
# Code Signing Certificates
# /techniques/T1587/002
# Digital Certificates
# /techniques/T1587/003
# Exploits
# /techniques/T1587/004
# 1
# Establish Accounts (2)
# /techniques/T1585
# Social Media Accounts
# /techniques/T1585/001
# Email Accounts
# /techniques/T1585/002
# 1
# Obtain Capabilities (6)
# /techniques/T1588
# Malware
# /techniques/T1588/001
# Tool
# /techniques/T1588/002
# Code Signing Certificates
# /techniques/T1588/003
# Digital Certificates
# /techniques/T1588/004
# Exploits
# /techniques/T1588/005
# Vulnerabilities
# /techniques/T1588/006
# Resource Development
# 3
# 0
# Drive-by Compromise
# /techniques/T1189
# 0
# Exploit Public-Facing Application
# /techniques/T1190
# 0
# External Remote Services
# /techniques/T1133
# 0
# Hardware Additions
# /techniques/T1200
# 1
# Phishing (3)
# /techniques/T1566
# Spearphishing Attachment
# /techniques/T1566/001
# Spearphishing Link
# /techniques/T1566/002
# Spearphishing via Service
# /techniques/T1566/003
# 0
# Replication Through Removable Media
# /techniques/T1091
# 1
# Supply Chain Compromise (3)
# /techniques/T1195
# Compromise Software Dependencies and Development Tools
# /techniques/T1195/001
# Compromise Software Supply Chain
# /techniques/T1195/002
# Compromise Hardware Supply Chain
# /techniques/T1195/003
# 0
# Trusted Relationship
# /techniques/T1199
# 1
# Valid Accounts (4)
# /techniques/T1078
# Default Accounts
# /techniques/T1078/001
# Domain Accounts
# /techniques/T1078/002
# Local Accounts
# /techniques/T1078/003
# Cloud Accounts
# /techniques/T1078/004
# Initial Access
# 5
# 1
# Command and Scripting Interpreter (8)
# /techniques/T1059
# PowerShell
# /techniques/T1059/001
# AppleScript
# /techniques/T1059/002
# Windows Command Shell
# /techniques/T1059/003
# Unix Shell
# /techniques/T1059/004
# Visual Basic
# /techniques/T1059/005
# Python
# /techniques/T1059/006
# JavaScript/JScript
# /techniques/T1059/007
# Network Device CLI
# /techniques/T1059/008
# 0
# Exploitation for Client Execution
# /techniques/T1203
# 1
# Inter-Process Communication (2)
# /techniques/T1559
# Component Object Model
# /techniques/T1559/001
# Dynamic Data Exchange
# /techniques/T1559/002
# 0
# Native API
# /techniques/T1106
# 1
# Scheduled Task/Job (6)
# /techniques/T1053
# At (Windows)
# /techniques/T1053/002
# Scheduled Task
# /techniques/T1053/005
# At (Linux)
# /techniques/T1053/001
# Launchd
# /techniques/T1053/004
# Cron
# /techniques/T1053/003
# Systemd Timers
# /techniques/T1053/006
# 0
# Shared Modules
# /techniques/T1129
# 0
# Software Deployment Tools
# /techniques/T1072
# 1
# System Services (2)
# /techniques/T1569
# Launchctl
# /techniques/T1569/001
# Service Execution
# /techniques/T1569/002
# 1
# User Execution (2)
# /techniques/T1204
# Malicious Link
# /techniques/T1204/001
# Malicious File
# /techniques/T1204/002
# 0
# Windows Management Instrumentation
# /techniques/T1047
# Execution
# 13
# 1
# Account Manipulation (4)
# /techniques/T1098
# Exchange Email Delegate Permissions
# /techniques/T1098/002
# Add Office 365 Global Administrator Role
# /techniques/T1098/003
# SSH Authorized Keys
# /techniques/T1098/004
# Additional Cloud Credentials
# /techniques/T1098/001
# 0
# BITS Jobs
# /techniques/T1197
# 1
# Boot or Logon Autostart Execution (12)
# /techniques/T1547
# Registry Run Keys / Startup Folder
# /techniques/T1547/001
# Authentication Package
# /techniques/T1547/002
# Time Providers
# /techniques/T1547/003
# Winlogon Helper DLL
# /techniques/T1547/004
# Security Support Provider
# /techniques/T1547/005
# Kernel Modules and Extensions
# /techniques/T1547/006
# Re-opened Applications
# /techniques/T1547/007
# LSASS Driver
# /techniques/T1547/008
# Shortcut Modification
# /techniques/T1547/009
# Port Monitors
# /techniques/T1547/010
# Plist Modification
# /techniques/T1547/011
# Print Processors
# /techniques/T1547/012
# 1
# Boot or Logon Initialization Scripts (5)
# /techniques/T1037
# Logon Script (Windows)
# /techniques/T1037/001
# Logon Script (Mac)
# /techniques/T1037/002
# Network Logon Script
# /techniques/T1037/003
# Rc.common
# /techniques/T1037/004
# Startup Items
# /techniques/T1037/005
# 0
# Browser Extensions
# /techniques/T1176
# 0
# Compromise Client Software Binary
# /techniques/T1554
# 1
# Create Account (3)
# /techniques/T1136
# Local Account
# /techniques/T1136/001
# Domain Account
# /techniques/T1136/002
# Cloud Account
# /techniques/T1136/003
# 1
# Create or Modify System Process (4)
# /techniques/T1543
# Launch Agent
# /techniques/T1543/001
# Systemd Service
# /techniques/T1543/002
# Windows Service
# /techniques/T1543/003
# Launch Daemon
# /techniques/T1543/004
# 1
# Event Triggered Execution (15)
# /techniques/T1546
# Change Default File Association
# /techniques/T1546/001
# Screensaver
# /techniques/T1546/002
# Windows Management Instrumentation Event Subscription
# /techniques/T1546/003
# .bash_profile and .bashrc
# /techniques/T1546/004
# Trap
# /techniques/T1546/005
# LC_LOAD_DYLIB Addition
# /techniques/T1546/006
# Netsh Helper DLL
# /techniques/T1546/007
# Accessibility Features
# /techniques/T1546/008
# AppCert DLLs
# /techniques/T1546/009
# AppInit DLLs
# /techniques/T1546/010
# Application Shimming
# /techniques/T1546/011
# Image File Execution Options Injection
# /techniques/T1546/012
# PowerShell Profile
# /techniques/T1546/013
# Emond
# /techniques/T1546/014
# Component Object Model Hijacking
# /techniques/T1546/015
# 0
# External Remote Services
# /techniques/T1133
# 1
# Hijack Execution Flow (11)
# /techniques/T1574
# Services File Permissions Weakness
# /techniques/T1574/010
# Executable Installer File Permissions Weakness
# /techniques/T1574/005
# Services Registry Permissions Weakness
# /techniques/T1574/011
# Path Interception by Unquoted Path
# /techniques/T1574/009
# Path Interception by PATH Environment Variable
# /techniques/T1574/007
# Path Interception by Search Order Hijacking
# /techniques/T1574/008
# DLL Search Order Hijacking
# /techniques/T1574/001
# DLL Side-Loading
# /techniques/T1574/002
# LD_PRELOAD
# /techniques/T1574/006
# Dylib Hijacking
# /techniques/T1574/004
# COR_PROFILER
# /techniques/T1574/012
# 0
# Implant Container Image
# /techniques/T1525
# 1
# Office Application Startup (6)
# /techniques/T1137
# Add-ins
# /techniques/T1137/006
# Office Template Macros
# /techniques/T1137/001
# Outlook Forms
# /techniques/T1137/003
# Outlook Rules
# /techniques/T1137/005
# Outlook Home Page
# /techniques/T1137/004
# Office Test
# /techniques/T1137/002
# 1
# Pre-OS Boot (5)
# /techniques/T1542
# System Firmware
# /techniques/T1542/001
# Component Firmware
# /techniques/T1542/002
# Bootkit
# /techniques/T1542/003
# ROMMONkit
# /techniques/T1542/004
# TFTP Boot
# /techniques/T1542/005
# 1
# Scheduled Task/Job (6)
# /techniques/T1053
# At (Windows)
# /techniques/T1053/002
# Scheduled Task
# /techniques/T1053/005
# At (Linux)
# /techniques/T1053/001
# Launchd
# /techniques/T1053/004
# Cron
# /techniques/T1053/003
# Systemd Timers
# /techniques/T1053/006
# 1
# Server Software Component (3)
# /techniques/T1505
# SQL Stored Procedures
# /techniques/T1505/001
# Transport Agent
# /techniques/T1505/002
# Web Shell
# /techniques/T1505/003
# 1
# Traffic Signaling (1)
# /techniques/T1205
# Port Knocking
# /techniques/T1205/001
# 1
# Valid Accounts (4)
# /techniques/T1078
# Default Accounts
# /techniques/T1078/001
# Domain Accounts
# /techniques/T1078/002
# Local Accounts
# /techniques/T1078/003
# Cloud Accounts
# /techniques/T1078/004
# Persistence
# 11
# 1
# Abuse Elevation Control Mechanism (4)
# /techniques/T1548
# Setuid and Setgid
# /techniques/T1548/001
# Bypass User Account Control
# /techniques/T1548/002
# Sudo and Sudo Caching
# /techniques/T1548/003
# Elevated Execution with Prompt
# /techniques/T1548/004
# 1
# Access Token Manipulation (5)
# /techniques/T1134
# Token Impersonation/Theft
# /techniques/T1134/001
# Create Process with Token
# /techniques/T1134/002
# Make and Impersonate Token
# /techniques/T1134/003
# Parent PID Spoofing
# /techniques/T1134/004
# SID-History Injection
# /techniques/T1134/005
# 1
# Boot or Logon Autostart Execution (12)
# /techniques/T1547
# Registry Run Keys / Startup Folder
# /techniques/T1547/001
# Authentication Package
# /techniques/T1547/002
# Time Providers
# /techniques/T1547/003
# Winlogon Helper DLL
# /techniques/T1547/004
# Security Support Provider
# /techniques/T1547/005
# Kernel Modules and Extensions
# /techniques/T1547/006
# Re-opened Applications
# /techniques/T1547/007
# LSASS Driver
# /techniques/T1547/008
# Shortcut Modification
# /techniques/T1547/009
# Port Monitors
# /techniques/T1547/010
# Plist Modification
# /techniques/T1547/011
# Print Processors
# /techniques/T1547/012
# 1
# Boot or Logon Initialization Scripts (5)
# /techniques/T1037
# Logon Script (Windows)
# /techniques/T1037/001
# Logon Script (Mac)
# /techniques/T1037/002
# Network Logon Script
# /techniques/T1037/003
# Rc.common
# /techniques/T1037/004
# Startup Items
# /techniques/T1037/005
# 1
# Create or Modify System Process (4)
# /techniques/T1543
# Launch Agent
# /techniques/T1543/001
# Systemd Service
# /techniques/T1543/002
# Windows Service
# /techniques/T1543/003
# Launch Daemon
# /techniques/T1543/004
# 1
# Domain Policy Modification (2)
# /techniques/T1484
# Group Policy Modification
# /techniques/T1484/001
# Domain Trust Modification
# /techniques/T1484/002
# 1
# Event Triggered Execution (15)
# /techniques/T1546
# Change Default File Association
# /techniques/T1546/001
# Screensaver
# /techniques/T1546/002
# Windows Management Instrumentation Event Subscription
# /techniques/T1546/003
# .bash_profile and .bashrc
# /techniques/T1546/004
# Trap
# /techniques/T1546/005
# LC_LOAD_DYLIB Addition
# /techniques/T1546/006
# Netsh Helper DLL
# /techniques/T1546/007
# Accessibility Features
# /techniques/T1546/008
# AppCert DLLs
# /techniques/T1546/009
# AppInit DLLs
# /techniques/T1546/010
# Application Shimming
# /techniques/T1546/011
# Image File Execution Options Injection
# /techniques/T1546/012
# PowerShell Profile
# /techniques/T1546/013
# Emond
# /techniques/T1546/014
# Component Object Model Hijacking
# /techniques/T1546/015
# 0
# Exploitation for Privilege Escalation
# /techniques/T1068
# 1
# Hijack Execution Flow (11)
# /techniques/T1574
# Services File Permissions Weakness
# /techniques/T1574/010
# Executable Installer File Permissions Weakness
# /techniques/T1574/005
# Services Registry Permissions Weakness
# /techniques/T1574/011
# Path Interception by Unquoted Path
# /techniques/T1574/009
# Path Interception by PATH Environment Variable
# /techniques/T1574/007
# Path Interception by Search Order Hijacking
# /techniques/T1574/008
# DLL Search Order Hijacking
# /techniques/T1574/001
# DLL Side-Loading
# /techniques/T1574/002
# LD_PRELOAD
# /techniques/T1574/006
# Dylib Hijacking
# /techniques/T1574/004
# COR_PROFILER
# /techniques/T1574/012
# 1
# Process Injection (11)
# /techniques/T1055
# Dynamic-link Library Injection
# /techniques/T1055/001
# Portable Executable Injection
# /techniques/T1055/002
# Thread Execution Hijacking
# /techniques/T1055/003
# Asynchronous Procedure Call
# /techniques/T1055/004
# Thread Local Storage
# /techniques/T1055/005
# Ptrace System Calls
# /techniques/T1055/008
# Proc Memory
# /techniques/T1055/009
# Extra Window Memory Injection
# /techniques/T1055/011
# Process Doppelg盲nging
# /techniques/T1055/013
# Process Hollowing
# /techniques/T1055/012
# VDSO Hijacking
# /techniques/T1055/014
# 1
# Scheduled Task/Job (6)
# /techniques/T1053
# At (Windows)
# /techniques/T1053/002
# Scheduled Task
# /techniques/T1053/005
# At (Linux)
# /techniques/T1053/001
# Launchd
# /techniques/T1053/004
# Cron
# /techniques/T1053/003
# Systemd Timers
# /techniques/T1053/006
# 1
# Valid Accounts (4)
# /techniques/T1078
# Default Accounts
# /techniques/T1078/001
# Domain Accounts
# /techniques/T1078/002
# Local Accounts
# /techniques/T1078/003
# Cloud Accounts
# /techniques/T1078/004
# Privilege Escalation
# 26
# 1
# Abuse Elevation Control Mechanism (4)
# /techniques/T1548
# Setuid and Setgid
# /techniques/T1548/001
# Bypass User Account Control
# /techniques/T1548/002
# Sudo and Sudo Caching
# /techniques/T1548/003
# Elevated Execution with Prompt
# /techniques/T1548/004
# 1
# Access Token Manipulation (5)
# /techniques/T1134
# Token Impersonation/Theft
# /techniques/T1134/001
# Create Process with Token
# /techniques/T1134/002
# Make and Impersonate Token
# /techniques/T1134/003
# Parent PID Spoofing
# /techniques/T1134/004
# SID-History Injection
# /techniques/T1134/005
# 0
# BITS Jobs
# /techniques/T1197
# 0
# Deobfuscate/Decode Files or Information
# /techniques/T1140
# 0
# Direct Volume Access
# /techniques/T1006
# 1
# Domain Policy Modification (2)
# /techniques/T1484
# Group Policy Modification
# /techniques/T1484/001
# Domain Trust Modification
# /techniques/T1484/002
# 1
# Execution Guardrails (1)
# /techniques/T1480
# Environmental Keying
# /techniques/T1480/001
# 0
# Exploitation for Defense Evasion
# /techniques/T1211
# 1
# File and Directory Permissions Modification (2)
# /techniques/T1222
# Windows File and Directory Permissions Modification
# /techniques/T1222/001
# Linux and Mac File and Directory Permissions Modification
# /techniques/T1222/002
# 1
# Hide Artifacts (7)
# /techniques/T1564
# Hidden Files and Directories
# /techniques/T1564/001
# Hidden Users
# /techniques/T1564/002
# Hidden Window
# /techniques/T1564/003
# NTFS File Attributes
# /techniques/T1564/004
# Hidden File System
# /techniques/T1564/005
# Run Virtual Instance
# /techniques/T1564/006
# VBA Stomping
# /techniques/T1564/007
# 1
# Hijack Execution Flow (11)
# /techniques/T1574
# Services File Permissions Weakness
# /techniques/T1574/010
# Executable Installer File Permissions Weakness
# /techniques/T1574/005
# Services Registry Permissions Weakness
# /techniques/T1574/011
# Path Interception by Unquoted Path
# /techniques/T1574/009
# Path Interception by PATH Environment Variable
# /techniques/T1574/007
# Path Interception by Search Order Hijacking
# /techniques/T1574/008
# DLL Search Order Hijacking
# /techniques/T1574/001
# DLL Side-Loading
# /techniques/T1574/002
# LD_PRELOAD
# /techniques/T1574/006
# Dylib Hijacking
# /techniques/T1574/004
# COR_PROFILER
# /techniques/T1574/012
# 1
# Impair Defenses (7)
# /techniques/T1562
# Disable or Modify Tools
# /techniques/T1562/001
# Disable Windows Event Logging
# /techniques/T1562/002
# Impair Command History Logging
# /techniques/T1562/003
# Disable or Modify System Firewall
# /techniques/T1562/004
# Indicator Blocking
# /techniques/T1562/006
# Disable or Modify Cloud Firewall
# /techniques/T1562/007
# Disable Cloud Logs
# /techniques/T1562/008
# 1
# Indicator Removal on Host (6)
# /techniques/T1070
# Clear Windows Event Logs
# /techniques/T1070/001
# Clear Linux or Mac System Logs
# /techniques/T1070/002
# Clear Command History
# /techniques/T1070/003
# File Deletion
# /techniques/T1070/004
# Network Share Connection Removal
# /techniques/T1070/005
# Timestomp
# /techniques/T1070/006
# 0
# Indirect Command Execution
# /techniques/T1202
# 1
# Masquerading (6)
# /techniques/T1036
# Invalid Code Signature
# /techniques/T1036/001
# Right-to-Left Override
# /techniques/T1036/002
# Rename System Utilities
# /techniques/T1036/003
# Masquerade Task or Service
# /techniques/T1036/004
# Match Legitimate Name or Location
# /techniques/T1036/005
# Space after Filename
# /techniques/T1036/006
# 1
# Modify Authentication Process (4)
# /techniques/T1556
# Domain Controller Authentication
# /techniques/T1556/001
# Password Filter DLL
# /techniques/T1556/002
# Pluggable Authentication Modules
# /techniques/T1556/003
# Network Device Authentication
# /techniques/T1556/004
# 1
# Modify Cloud Compute Infrastructure (4)
# /techniques/T1578
# Create Snapshot
# /techniques/T1578/001
# Create Cloud Instance
# /techniques/T1578/002
# Delete Cloud Instance
# /techniques/T1578/003
# Revert Cloud Instance
# /techniques/T1578/004
# 0
# Modify Registry
# /techniques/T1112
# 1
# Modify System Image (2)
# /techniques/T1601
# Patch System Image
# /techniques/T1601/001
# Downgrade System Image
# /techniques/T1601/002
# 1
# Network Boundary Bridging (1)
# /techniques/T1599
# Network Address Translation Traversal
# /techniques/T1599/001
# 1
# Obfuscated Files or Information (5)
# /techniques/T1027
# Binary Padding
# /techniques/T1027/001
# Software Packing
# /techniques/T1027/002
# Steganography
# /techniques/T1027/003
# Compile After Delivery
# /techniques/T1027/004
# Indicator Removal from Tools
# /techniques/T1027/005
# 1
# Pre-OS Boot (5)
# /techniques/T1542
# System Firmware
# /techniques/T1542/001
# Component Firmware
# /techniques/T1542/002
# Bootkit
# /techniques/T1542/003
# ROMMONkit
# /techniques/T1542/004
# TFTP Boot
# /techniques/T1542/005
# 1
# Process Injection (11)
# /techniques/T1055
# Dynamic-link Library Injection
# /techniques/T1055/001
# Portable Executable Injection
# /techniques/T1055/002
# Thread Execution Hijacking
# /techniques/T1055/003
# Asynchronous Procedure Call
# /techniques/T1055/004
# Thread Local Storage
# /techniques/T1055/005
# Ptrace System Calls
# /techniques/T1055/008
# Proc Memory
# /techniques/T1055/009
# Extra Window Memory Injection
# /techniques/T1055/011
# Process Doppelg盲nging
# /techniques/T1055/013
# Process Hollowing
# /techniques/T1055/012
# VDSO Hijacking
# /techniques/T1055/014
# 0
# Rogue Domain Controller
# /techniques/T1207
# 0
# Rootkit
# /techniques/T1014
# 1
# Signed Binary Proxy Execution (11)
# /techniques/T1218
# Rundll32
# /techniques/T1218/011
# Compiled HTML File
# /techniques/T1218/001
# Control Panel
# /techniques/T1218/002
# CMSTP
# /techniques/T1218/003
# InstallUtil
# /techniques/T1218/004
# Mshta
# /techniques/T1218/005
# Regsvcs/Regasm
# /techniques/T1218/009
# Regsvr32
# /techniques/T1218/010
# Msiexec
# /techniques/T1218/007
# Odbcconf
# /techniques/T1218/008
# Verclsid
# /techniques/T1218/012
# 1
# Signed Script Proxy Execution (1)
# /techniques/T1216
# PubPrn
# /techniques/T1216/001
# 1
# Subvert Trust Controls (4)
# /techniques/T1553
# Gatekeeper Bypass
# /techniques/T1553/001
# Code Signing
# /techniques/T1553/002
# SIP and Trust Provider Hijacking
# /techniques/T1553/003
# Install Root Certificate
# /techniques/T1553/004
# 0
# Template Injection
# /techniques/T1221
# 1
# Traffic Signaling (1)
# /techniques/T1205
# Port Knocking
# /techniques/T1205/001
# 1
# Trusted Developer Utilities Proxy Execution (1)
# /techniques/T1127
# MSBuild
# /techniques/T1127/001
# 0
# Unused/Unsupported Cloud Regions
# /techniques/T1535
# 1
# Use Alternate Authentication Material (4)
# /techniques/T1550
# Pass the Hash
# /techniques/T1550/002
# Pass the Ticket
# /techniques/T1550/003
# Application Access Token
# /techniques/T1550/001
# Web Session Cookie
# /techniques/T1550/004
# 1
# Valid Accounts (4)
# /techniques/T1078
# Default Accounts
# /techniques/T1078/001
# Domain Accounts
# /techniques/T1078/002
# Local Accounts
# /techniques/T1078/003
# Cloud Accounts
# /techniques/T1078/004
# 1
# Virtualization/Sandbox Evasion (3)
# /techniques/T1497
# System Checks
# /techniques/T1497/001
# User Activity Based Checks
# /techniques/T1497/002
# Time Based Evasion
# /techniques/T1497/003
# 1
# Weaken Encryption (2)
# /techniques/T1600
# Reduce Key Space
# /techniques/T1600/001
# Disable Crypto Hardware
# /techniques/T1600/002
# 0
# XSL Script Processing
# /techniques/T1220
# Defense Evasion
# 9
# 1
# Brute Force (4)
# /techniques/T1110
# Password Guessing
# /techniques/T1110/001
# Password Cracking
# /techniques/T1110/002
# Password Spraying
# /techniques/T1110/003
# Credential Stuffing
# /techniques/T1110/004
# 1
# Credentials from Password Stores (3)
# /techniques/T1555
# Keychain
# /techniques/T1555/001
# Securityd Memory
# /techniques/T1555/002
# Credentials from Web Browsers
# /techniques/T1555/003
# 0
# Exploitation for Credential Access
# /techniques/T1212
# 0
# Forced Authentication
# /techniques/T1187
# 1
# Forge Web Credentials (2)
# /techniques/T1606
# Web Cookies
# /techniques/T1606/001
# SAML Tokens
# /techniques/T1606/002
# 1
# Input Capture (4)
# /techniques/T1056
# Keylogging
# /techniques/T1056/001
# GUI Input Capture
# /techniques/T1056/002
# Web Portal Capture
# /techniques/T1056/003
# Credential API Hooking
# /techniques/T1056/004
# 1
# Man-in-the-Middle (2)
# /techniques/T1557
# LLMNR/NBT-NS Poisoning and SMB Relay
# /techniques/T1557/001
# ARP Cache Poisoning
# /techniques/T1557/002
# 1
# Modify Authentication Process (4)
# /techniques/T1556
# Domain Controller Authentication
# /techniques/T1556/001
# Password Filter DLL
# /techniques/T1556/002
# Pluggable Authentication Modules
# /techniques/T1556/003
# Network Device Authentication
# /techniques/T1556/004
# 0
# Network Sniffing
# /techniques/T1040
# 1
# OS Credential Dumping (8)
# /techniques/T1003
# LSASS Memory
# /techniques/T1003/001
# Security Account Manager
# /techniques/T1003/002
# NTDS
# /techniques/T1003/003
# DCSync
# /techniques/T1003/006
# Proc Filesystem
# /techniques/T1003/007
# /etc/passwd and /etc/shadow
# /techniques/T1003/008
# Cached Domain Credentials
# /techniques/T1003/005
# LSA Secrets
# /techniques/T1003/004
# 0
# Steal Application Access Token
# /techniques/T1528
# 1
# Steal or Forge Kerberos Tickets (4)
# /techniques/T1558
# Golden Ticket
# /techniques/T1558/001
# Silver Ticket
# /techniques/T1558/002
# Kerberoasting
# /techniques/T1558/003
# AS-REP Roasting
# /techniques/T1558/004
# 0
# Steal Web Session Cookie
# /techniques/T1539
# 0
# Two-Factor Authentication Interception
# /techniques/T1111
# 1
# Unsecured Credentials (6)
# /techniques/T1552
# Credentials In Files
# /techniques/T1552/001
# Credentials in Registry
# /techniques/T1552/002
# Bash History
# /techniques/T1552/003
# Private Keys
# /techniques/T1552/004
# Cloud Instance Metadata API
# /techniques/T1552/005
# Group Policy Preferences
# /techniques/T1552/006
# Credential Access
# 4
# 1
# Account Discovery (4)
# /techniques/T1087
# Local Account
# /techniques/T1087/001
# Domain Account
# /techniques/T1087/002
# Email Account
# /techniques/T1087/003
# Cloud Account
# /techniques/T1087/004
# 0
# Application Window Discovery
# /techniques/T1010
# 0
# Browser Bookmark Discovery
# /techniques/T1217
# 0
# Cloud Infrastructure Discovery
# /techniques/T1580
# 0
# Cloud Service Dashboard
# /techniques/T1538
# 0
# Cloud Service Discovery
# /techniques/T1526
# 0
# Domain Trust Discovery
# /techniques/T1482
# 0
# File and Directory Discovery
# /techniques/T1083
# 0
# Network Service Scanning
# /techniques/T1046
# 0
# Network Share Discovery
# /techniques/T1135
# 0
# Network Sniffing
# /techniques/T1040
# 0
# Password Policy Discovery
# /techniques/T1201
# 0
# Peripheral Device Discovery
# /techniques/T1120
# 1
# Permission Groups Discovery (3)
# /techniques/T1069
# Domain Groups
# /techniques/T1069/002
# Cloud Groups
# /techniques/T1069/003
# Local Groups
# /techniques/T1069/001
# 0
# Process Discovery
# /techniques/T1057
# 0
# Query Registry
# /techniques/T1012
# 0
# Remote System Discovery
# /techniques/T1018
# 1
# Software Discovery (1)
# /techniques/T1518
# Security Software Discovery
# /techniques/T1518/001
# 0
# System Information Discovery
# /techniques/T1082
# 0
# System Network Configuration Discovery
# /techniques/T1016
# 0
# System Network Connections Discovery
# /techniques/T1049
# 0
# System Owner/User Discovery
# /techniques/T1033
# 0
# System Service Discovery
# /techniques/T1007
# 0
# System Time Discovery
# /techniques/T1124
# 1
# Virtualization/Sandbox Evasion (3)
# /techniques/T1497
# System Checks
# /techniques/T1497/001
# User Activity Based Checks
# /techniques/T1497/002
# Time Based Evasion
# /techniques/T1497/003
# Discovery
# 3
# 0
# Exploitation of Remote Services
# /techniques/T1210
# 0
# Internal Spearphishing
# /techniques/T1534
# 0
# Lateral Tool Transfer
# /techniques/T1570
# 1
# Remote Service Session Hijacking (2)
# /techniques/T1563
# SSH Hijacking
# /techniques/T1563/001
# RDP Hijacking
# /techniques/T1563/002
# 1
# Remote Services (6)
# /techniques/T1021
# Remote Desktop Protocol
# /techniques/T1021/001
# SMB/Windows Admin Shares
# /techniques/T1021/002
# Distributed Component Object Model
# /techniques/T1021/003
# SSH
# /techniques/T1021/004
# VNC
# /techniques/T1021/005
# Windows Remote Management
# /techniques/T1021/006
# 0
# Replication Through Removable Media
# /techniques/T1091
# 0
# Software Deployment Tools
# /techniques/T1072
# 0
# Taint Shared Content
# /techniques/T1080
# 1
# Use Alternate Authentication Material (4)
# /techniques/T1550
# Pass the Hash
# /techniques/T1550/002
# Pass the Ticket
# /techniques/T1550/003
# Application Access Token
# /techniques/T1550/001
# Web Session Cookie
# /techniques/T1550/004
# Lateral Movement
# 7
# 1
# Archive Collected Data (3)
# /techniques/T1560
# Archive via Utility
# /techniques/T1560/001
# Archive via Library
# /techniques/T1560/002
# Archive via Custom Method
# /techniques/T1560/003
# 0
# Audio Capture
# /techniques/T1123
# 0
# Automated Collection
# /techniques/T1119
# 0
# Clipboard Data
# /techniques/T1115
# 0
# Data from Cloud Storage Object
# /techniques/T1530
# 1
# Data from Configuration Repository (2)
# /techniques/T1602
# SNMP (MIB Dump)
# /techniques/T1602/001
# Network Device Configuration Dump
# /techniques/T1602/002
# 1
# Data from Information Repositories (2)
# /techniques/T1213
# Confluence
# /techniques/T1213/001
# Sharepoint
# /techniques/T1213/002
# 0
# Data from Local System
# /techniques/T1005
# 0
# Data from Network Shared Drive
# /techniques/T1039
# 0
# Data from Removable Media
# /techniques/T1025
# 1
# Data Staged (2)
# /techniques/T1074
# Local Data Staging
# /techniques/T1074/001
# Remote Data Staging
# /techniques/T1074/002
# 1
# Email Collection (3)
# /techniques/T1114
# Local Email Collection
# /techniques/T1114/001
# Remote Email Collection
# /techniques/T1114/002
# Email Forwarding Rule
# /techniques/T1114/003
# 1
# Input Capture (4)
# /techniques/T1056
# Keylogging
# /techniques/T1056/001
# GUI Input Capture
# /techniques/T1056/002
# Web Portal Capture
# /techniques/T1056/003
# Credential API Hooking
# /techniques/T1056/004
# 0
# Man in the Browser
# /techniques/T1185
# 1
# Man-in-the-Middle (2)
# /techniques/T1557
# LLMNR/NBT-NS Poisoning and SMB Relay
# /techniques/T1557/001
# ARP Cache Poisoning
# /techniques/T1557/002
# 0
# Screen Capture
# /techniques/T1113
# 0
# Video Capture
# /techniques/T1125
# Collection
# 8
# 1
# Application Layer Protocol (4)
# /techniques/T1071
# Web Protocols
# /techniques/T1071/001
# File Transfer Protocols
# /techniques/T1071/002
# Mail Protocols
# /techniques/T1071/003
# DNS
# /techniques/T1071/004
# 0
# Communication Through Removable Media
# /techniques/T1092
# 1
# Data Encoding (2)
# /techniques/T1132
# Standard Encoding
# /techniques/T1132/001
# Non-Standard Encoding
# /techniques/T1132/002
# 1
# Data Obfuscation (3)
# /techniques/T1001
# Junk Data
# /techniques/T1001/001
# Steganography
# /techniques/T1001/002
# Protocol Impersonation
# /techniques/T1001/003
# 1
# Dynamic Resolution (3)
# /techniques/T1568
# Domain Generation Algorithms
# /techniques/T1568/002
# Fast Flux DNS
# /techniques/T1568/001
# DNS Calculation
# /techniques/T1568/003
# 1
# Encrypted Channel (2)
# /techniques/T1573
# Symmetric Cryptography
# /techniques/T1573/001
# Asymmetric Cryptography
# /techniques/T1573/002
# 0
# Fallback Channels
# /techniques/T1008
# 0
# Ingress Tool Transfer
# /techniques/T1105
# 0
# Multi-Stage Channels
# /techniques/T1104
# 0
# Non-Application Layer Protocol
# /techniques/T1095
# 0
# Non-Standard Port
# /techniques/T1571
# 0
# Protocol Tunneling
# /techniques/T1572
# 1
# Proxy (4)
# /techniques/T1090
# Internal Proxy
# /techniques/T1090/001
# External Proxy
# /techniques/T1090/002
# Multi-hop Proxy
# /techniques/T1090/003
# Domain Fronting
# /techniques/T1090/004
# 0
# Remote Access Software
# /techniques/T1219
# 1
# Traffic Signaling (1)
# /techniques/T1205
# Port Knocking
# /techniques/T1205/001
# 1
# Web Service (3)
# /techniques/T1102
# Dead Drop Resolver
# /techniques/T1102/001
# Bidirectional Communication
# /techniques/T1102/002
# One-Way Communication
# /techniques/T1102/003
# Command and Control
# 5
# 1
# Automated Exfiltration (1)
# /techniques/T1020
# Traffic Duplication
# /techniques/T1020/001
# 0
# Data Transfer Size Limits
# /techniques/T1030
# 1
# Exfiltration Over Alternative Protocol (3)
# /techniques/T1048
# Exfiltration Over Symmetric Encrypted Non-C2 Protocol
# /techniques/T1048/001
# Exfiltration Over Asymmetric Encrypted Non-C2 Protocol
# /techniques/T1048/002
# Exfiltration Over Unencrypted/Obfuscated Non-C2 Protocol
# /techniques/T1048/003
# 0
# Exfiltration Over C2 Channel
# /techniques/T1041
# 1
# Exfiltration Over Other Network Medium (1)
# /techniques/T1011
# Exfiltration Over Bluetooth
# /techniques/T1011/001
# 1
# Exfiltration Over Physical Medium (1)
# /techniques/T1052
# Exfiltration over USB
# /techniques/T1052/001
# 1
# Exfiltration Over Web Service (2)
# /techniques/T1567
# Exfiltration to Code Repository
# /techniques/T1567/001
# Exfiltration to Cloud Storage
# /techniques/T1567/002
# 0
# Scheduled Transfer
# /techniques/T1029
# 0
# Transfer Data to Cloud Account
# /techniques/T1537
# Exfiltration
# 5
# 0
# Account Access Removal
# /techniques/T1531
# 0
# Data Destruction
# /techniques/T1485
# 0
# Data Encrypted for Impact
# /techniques/T1486
# 1
# Data Manipulation (3)
# /techniques/T1565
# Stored Data Manipulation
# /techniques/T1565/001
# Transmitted Data Manipulation
# /techniques/T1565/002
# Runtime Data Manipulation
# /techniques/T1565/003
# 1
# Defacement (2)
# /techniques/T1491
# Internal Defacement
# /techniques/T1491/001
# External Defacement
# /techniques/T1491/002
# 1
# Disk Wipe (2)
# /techniques/T1561
# Disk Content Wipe
# /techniques/T1561/001
# Disk Structure Wipe
# /techniques/T1561/002
# 1
# Endpoint Denial of Service (4)
# /techniques/T1499
# OS Exhaustion Flood
# /techniques/T1499/001
# Service Exhaustion Flood
# /techniques/T1499/002
# Application Exhaustion Flood
# /techniques/T1499/003
# Application or System Exploitation
# /techniques/T1499/004
# 0
# Firmware Corruption
# /techniques/T1495
# 0
# Inhibit System Recovery
# /techniques/T1490
# 1
# Network Denial of Service (2)
# /techniques/T1498
# Direct Network Flood
# /techniques/T1498/001
# Reflection Amplification
# /techniques/T1498/002
# 0
# Resource Hijacking
# /techniques/T1496
# 0
# Service Stop
# /techniques/T1489
# 0
# System Shutdown/Reboot
# /techniques/T1529

# %%
import requests

for techniques in G.nodes():
#     print(G.nodes[techniques]['url'])
    if G.nodes[techniques]['types'].find('technique') != -1:
        technique_url = G.nodes[techniques]['url']
        print(technique_url)
        technique_html = requests.get('https://attack.mitre.org' + technique_url).text
        
        soup = BeautifulSoup(technique_html)
        reference = soup.find('span', {'class': 'scite-citation'})
        print(reference)
# Out:
# /techniques/T1595
# <span class="scite-citation" id="scite-1">
# <span class="scite-citation-text">
# <a class="external text" href="https://www.caida.org/publications/papers/2012/analysis_slash_zero/analysis_slash_zero.pdf" name="scite-1" rel="nofollow" target="_blank">
#                         Dainotti, A. et al. (2012). Analysis of a “/0” Stealth Scan from a Botnet. Retrieved October 20, 2020.
#                     </a>
# </span>
# </span>
# /techniques/T1595/001
# <span class="scite-citation" id="scite-1">
# <span class="scite-citation-text">
# <a class="external text" href="https://www.caida.org/publications/papers/2012/analysis_slash_zero/analysis_slash_zero.pdf" name="scite-1" rel="nofollow" target="_blank">
#                         Dainotti, A. et al. (2012). Analysis of a “/0” Stealth Scan from a Botnet. Retrieved October 20, 2020.
#                     </a>
# </span>
# </span>
# /techniques/T1595/002
# -------------------------------------------------------------------------
# KeyboardInterrupt                       Traceback (most recent call last)
# <ipython-input-34-b9667f44c7f5> in <module>
#       8         technique_html = requests.get('https://attack.mitre.org' + technique_url).text
#       9
# ---> 10         soup = BeautifulSoup(technique_html)
#      11         reference = soup.find('span', {'class': 'scite-citation'})
#      12         print(reference)
#
# c:\python39\lib\site-packages\bs4\__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     346             self.reset()
#     347             try:
# --> 348                 self._feed()
#     349                 success = True
#     350                 break
#
# c:\python39\lib\site-packages\bs4\__init__.py in _feed(self)
#     432         self.builder.reset()
#     433
# --> 434         self.builder.feed(self.markup)
#     435         # Close out any unfinished strings and close all the open tags.
#     436         self.endData()
#
# c:\python39\lib\site-packages\bs4\builder\_htmlparser.py in feed(self, markup)
#     375         parser.soup = self.soup
#     376         try:
# --> 377             parser.feed(markup)
#     378             parser.close()
#     379         except HTMLParseError as e:
#
# c:\python39\lib\html\parser.py in feed(self, data)
#     108         """
#     109         self.rawdata = self.rawdata + data
# --> 110         self.goahead(0)
#     111
#     112     def close(self):
#
# c:\python39\lib\html\parser.py in goahead(self, end)
#     170                     k = self.parse_starttag(i)
#     171                 elif startswith("</", i):
# --> 172                     k = self.parse_endtag(i)
#     173                 elif startswith("<!--", i):
#     174                     k = self.parse_comment(i)
#
# c:\python39\lib\html\parser.py in parse_endtag(self, i)
#     418                 return gtpos
#     419
# --> 420         self.handle_endtag(elem)
#     421         self.clear_cdata_mode()
#     422         return gtpos
#
# c:\python39\lib\site-packages\bs4\builder\_htmlparser.py in handle_endtag(self, name, check_already_closed)
#     185             self.already_closed_empty_element.remove(name)
#     186         else:
# --> 187             self.soup.handle_endtag(name)
#     188
#     189     def handle_data(self, data):
#
# c:\python39\lib\site-packages\bs4\__init__.py in handle_endtag(self, name, nsprefix)
#     721         """
#     722         #print("End tag: " + name)
# --> 723         self.endData()
#     724         self._popToTag(name, nsprefix)
#     725
#
# c:\python39\lib\site-packages\bs4\__init__.py in endData(self, containerClass)
#     572
#     573             o = containerClass(current_data)
# --> 574             self.object_was_parsed(o)
#     575
#     576     def object_was_parsed(self, o, parent=None, most_recent_element=None):
#
# c:\python39\lib\site-packages\bs4\__init__.py in object_was_parsed(self, o, parent, most_recent_element)
#     593         fix = parent.next_element is not None
#     594
# --> 595         o.setup(parent, previous_element, next_element, previous_sibling, next_sibling)
#     596
#     597         self._most_recent_element = o
#
# c:\python39\lib\site-packages\bs4\element.py in setup(self, parent, previous_element, next_element, previous_sibling, next_sibling)
#     195         self.previous_sibling = previous_sibling
#     196         if previous_sibling is not None:
# --> 197             self.previous_sibling.next_sibling = self
#     198
#     199     def format_string(self, s, formatter):
#
# KeyboardInterrupt:
